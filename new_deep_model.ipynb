# %%
import os
from PIL import Image
import numpy as np

# Corrected Paths
image_dir = r'C:\Users\ALI\Documents\led_sensing\dataset\image_mask_data\Image'
mask_dir  = r'C:\Users\ALI\Documents\led_sensing\dataset\image_mask_data\Mask'

# Get sorted file lists to align images and masks
image_files = sorted([f for f in os.listdir(image_dir) if f.endswith('.png')])
mask_files = sorted([f for f in os.listdir(mask_dir) if f.endswith('.png')])

X = []
Y = []

# Load each image-mask pair
for img_file, mask_file in zip(image_files, mask_files):
    # Load image
    img_path = os.path.join(image_dir, img_file)
    img = Image.open(img_path).convert('L').resize((25, 25))
    img_array = np.array(img, dtype=np.float32) / 255.0
    img_array = np.expand_dims(img_array, axis=-1)

    # Load corresponding mask

# %%
print("Number of loaded images:", len(X))
print("Shape of X array:", X.shape if len(X) > 0 else "X is empty")
print("Example filenames:", image_files[:3])
# Out:
# Number of loaded images: 0
# Shape of X array: X is empty
# Example filenames: ['LED_Matrix_2025_02_24_22_52_37_1.png', 'LED_Matrix_2025_02_24_22_52_37_2.png', 'LED_Matrix_2025_02_24_22_52_37_3.png']

# %%
print("Image files:", len(image_files))
print("Mask files:", len(mask_files))
print("Example image:", image_files[0])
print("Example mask :", mask_files[0])
# Out:
# Image files: 822
# Mask files: 822
# Example image: LED_Matrix_2025_02_24_22_52_37_1.png
# Example mask : LED_Matrix_2025_02_24_22_52_37_1.png

# %%
X = []
Y = []

for img_file, mask_file in zip(image_files, mask_files):
    try:
        # Full paths
        img_path = os.path.join(image_dir, img_file)
        mask_path = os.path.join(mask_dir, mask_file)

        # Load and preprocess image
        img = Image.open(img_path).convert('L').resize((25, 25))
        img_array = np.array(img, dtype=np.float32) / 255.0
        img_array = np.expand_dims(img_array, axis=-1)

        # Load and preprocess mask
        mask = Image.open(mask_path).convert('L').resize((25, 25))
        mask_array = np.array(mask, dtype=np.float32) / 255.0
        mask_array = np.expand_dims(mask_array, axis=-1)

        # Append to datasets
        X.append(img_array)
        Y.append(mask_array)

    except Exception as e:
        print(f"Error processing {img_file} or {mask_file}: {e}")

# %%
import numpy as np
from sklearn.model_selection import train_test_split

# Convert to numpy arrays
X = np.array(X)
Y = np.array(Y)

# Split dataset: 80% train / 20% test
X_train, X_test, Y_train, Y_test = train_test_split(
    X, Y, test_size=0.2, random_state=42
)

print("Train:", X_train.shape, Y_train.shape)
print("Test :", X_test.shape, Y_test.shape)
# Out:
# Train: (657, 25, 25, 1) (657, 25, 25, 1)
# Test : (165, 25, 25, 1) (165, 25, 25, 1)

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from sklearn.metrics import precision_score, recall_score, f1_score

# --- Helper Functions ---

def plot_sample_predictions(X, y_true, y_pred, num_samples=3, threshold=0.5):
    plt.figure(figsize=(15, 5*num_samples))
    X = X.numpy() if tf.is_tensor(X) else X
    y_true = y_true.numpy() if tf.is_tensor(y_true) else y_true
    y_pred = y_pred.numpy() if tf.is_tensor(y_pred) else y_pred

    for i in range(num_samples):
        idx = np.random.randint(0, len(X))
        plt.subplot(num_samples, 3, i*3 + 1)
        plt.imshow(X[idx].squeeze(), cmap='viridis')
        plt.title(f'Sample {idx+1} - Input')
        plt.colorbar()

        plt.subplot(num_samples, 3, i*3 + 2)
        plt.imshow(y_true[idx].squeeze(), cmap='binary', vmin=0, vmax=1)
        plt.title('True Label')

        plt.subplot(num_samples, 3, i*3 + 3)
        plt.imshow((y_pred[idx] > threshold).squeeze(), cmap='binary', vmin=0, vmax=1)
        plt.title(f'Prediction (Threshold={threshold})')
    plt.tight_layout()
    plt.show()

def create_model():
    model = tf.keras.Sequential([
        tf.keras.layers.Input(shape=(25, 25, 1)),
        tf.keras.layers.Conv2D(32, 3, activation='relu', padding='same'),
        tf.keras.layers.MaxPooling2D(2),
        tf.keras.layers.Dropout(0.25),
        tf.keras.layers.Conv2D(64, 3, activation='relu', padding='same'),
        tf.keras.layers.MaxPooling2D(2),
        tf.keras.layers.Dropout(0.25),
        tf.keras.layers.UpSampling2D(),  # Upsample back to 13x13
        tf.keras.layers.UpSampling2D(),  # Upsample again to 25x25
        tf.keras.layers.Conv2D(1, 1, activation='sigmoid', padding='same')  # Match mask shape
    ])
    return model


def focal_loss(gamma=2.0, alpha=0.25):
    def focal_loss_fn(y_true, y_pred):
        y_pred = tf.clip_by_value(y_pred, 1e-7, 1 - 1e-7)
        p_t = y_true * y_pred + (1 - y_true) * (1 - y_pred)
        alpha_t = y_true * alpha + (1 - y_true) * (1 - alpha)
        focal_loss = -alpha_t * tf.pow(1.0 - p_t, gamma) * tf.math.log(p_t)
        return tf.reduce_mean(focal_loss)
    return focal_loss_fn

def iou_metric(y_true, y_pred, threshold=0.5):
    y_pred = tf.cast(y_pred > threshold, tf.float32)
    y_true = tf.cast(y_true, tf.float32)
    intersection = tf.reduce_sum(y_true * y_pred)
    union = tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) - intersection
    return (intersection + 1e-7) / (union + 1e-7)

def plot_history(history, title):
    plt.figure(figsize=(12, 4))
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'], label='Train')
    plt.plot(history.history['val_accuracy'], label='Validation')
    plt.title(f'{title} - Accuracy')
    plt.xlabel('Epoch')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'], label='Train')
    plt.plot(history.history['val_loss'], label='Validation')
    plt.title(f'{title} - Loss')
    plt.xlabel('Epoch')
    plt.legend()
    plt.tight_layout()
    plt.show()

def find_optimal_threshold(y_true, y_pred_proba):
    y_true_np = y_true.numpy() if tf.is_tensor(y_true) else y_true
    y_pred_np = y_pred_proba.numpy() if tf.is_tensor(y_pred_proba) else y_pred_proba
    thresholds = np.linspace(0.1, 0.9, 50)
    f1_scores = []

    for thresh in thresholds:
        y_pred = (y_pred_np > thresh).astype(np.float32)
        f1 = f1_score(y_true_np.reshape(-1), y_pred.reshape(-1))
        f1_scores.append(f1)

    best_threshold = thresholds[np.argmax(f1_scores)]
    plt.figure(figsize=(10, 5))
    plt.plot(thresholds, f1_scores, 'b-')
    plt.axvline(x=best_threshold, color='r', linestyle='--')
    plt.title(f'Optimal Threshold: {best_threshold:.3f}')
    plt.xlabel('Threshold')
    plt.ylabel('F1 Score')
    plt.grid(True)
    plt.show()
    return best_threshold

# %%
# Convert to float32 if needed
X_train_np = X_train.astype('float32')
y_train_np = Y_train.astype('float32')
X_test_np = X_test.astype('float32')
y_test_np = Y_test.astype('float32')

# Create and compile model
model_focal = create_model()
model_focal.compile(
    optimizer='adam',
    loss=focal_loss(),
    metrics=['accuracy', tf.keras.metrics.Recall(), tf.keras.metrics.Precision()]
)

# Early stopping
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss', patience=5, restore_best_weights=True
)

# Train
history_focal = model_focal.fit(
    X_train_np, y_train_np,
    epochs=50,
    batch_size=16,
    validation_split=0.1,
    callbacks=[early_stopping],
    verbose=1
)

# Plot training history
plot_history(history_focal, "Focal Loss Model")

# Predict
y_pred_proba = model_focal.predict(X_test_np)

# Optimal threshold
best_threshold = find_optimal_threshold(y_test_np, y_pred_proba)
print(f"Optimal Threshold: {best_threshold:.3f}")

# Visualize predictions
plot_sample_predictions(X_test_np, y_test_np, y_pred_proba, threshold=best_threshold)

# Final evaluation
y_pred_binary = (y_pred_proba > best_threshold).astype(np.float32)

iou_final = iou_metric(y_test_np, y_pred_binary, best_threshold).numpy()
f1_final = f1_score(y_test_np.reshape(-1), y_pred_binary.reshape(-1))
precision_final = precision_score(y_test_np.reshape(-1), y_pred_binary.reshape(-1))
recall_final = recall_score(y_test_np.reshape(-1), y_pred_binary.reshape(-1))

print("\nFinal Metrics:")
print(f"IoU: {iou_final:.4f}")
print(f"Precision: {precision_final:.4f}")
print(f"Recall: {recall_final:.4f}")
print(f"F1 Score: {f1_final:.4f}")

# Sample-wise accuracy
sample_accuracies = [
    np.mean((y_pred_proba[i] > best_threshold) == (y_test_np[i] > 0.5))
    for i in range(len(y_test_np))
]
print(f"\nSample-wise Accuracy:")
print(f"Average: {np.mean(sample_accuracies):.2%}")
print(f"Minimum: {min(sample_accuracies):.2%}")
print(f"Maximum: {max(sample_accuracies):.2%}")
# Out:
# Epoch 1/50
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 21
#      16 early_stopping = tf.keras.callbacks.EarlyStopping(
#      17     monitor='val_loss', patience=5, restore_best_weights=True
#      18 )
#      20 # Train
# ---> 21 history_focal = model_focal.fit(
#      22     X_train_np, y_train_np,
#      23     epochs=50,
#      24     batch_size=16,
#      25     validation_split=0.1,
#      26     callbacks=[early_stopping],
#      27     verbose=1
#      28 )
#      30 # Plot training history
#      31 plot_history(history_focal, "Focal Loss Model")
#
# File ~\anaconda3\Lib\site-packages\keras\src\utils\traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# Cell In[19], line 50, in focal_loss.<locals>.focal_loss_fn(y_true, y_pred)
#      48 def focal_loss_fn(y_true, y_pred):
#      49     y_pred = tf.clip_by_value(y_pred, 1e-7, 1 - 1e-7)
# ---> 50     p_t = y_true * y_pred + (1 - y_true) * (1 - y_pred)
#      51     alpha_t = y_true * alpha + (1 - y_true) * (1 - alpha)
#      52     focal_loss = -alpha_t * tf.pow(1.0 - p_t, gamma) * tf.math.log(p_t)
#
# ValueError: Dimensions must be equal, but are 25 and 24 for '{{node compile_loss/focal_loss_fn/mul}} = Mul[T=DT_FLOAT](data_1, compile_loss/focal_loss_fn/clip_by_value)' with input shapes: [?,25,25,1], [?,24,24,1].

# %%
import os
from PIL import Image
import numpy as np
from sklearn.model_selection import train_test_split

image_dir = r'C:\Users\ALI\Documents\led_sensing\dataset\image_mask_data\Image'
mask_dir  = r'C:\Users\ALI\Documents\led_sensing\dataset\image_mask_data\Mask'

image_files = sorted([f for f in os.listdir(image_dir) if f.endswith('.png')])
mask_files  = sorted([f for f in os.listdir(mask_dir) if f.endswith('.png')])

X, Y = [], []

for img_file, mask_file in zip(image_files, mask_files):
    img = Image.open(os.path.join(image_dir, img_file)).convert('L').resize((25, 25))
    mask = Image.open(os.path.join(mask_dir, mask_file)).convert('L').resize((25, 25))

    img_arr = np.expand_dims(np.array(img, dtype=np.float32) / 255.0, axis=-1)
    mask_arr = np.expand_dims(np.array(mask, dtype=np.float32) / 255.0, axis=-1)

    X.append(img_arr)
    Y.append(mask_arr)

X = np.array(X)
Y = np.array(Y)

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
X_train_np = X_train.astype('float32')
Y_train_np = Y_train.astype('float32')
X_test_np  = X_test.astype('float32')
Y_test_np  = Y_test.astype('float32')

# %%
def create_model():
    model = tf.keras.Sequential([
        tf.keras.layers.Input(shape=(25, 25, 1)),
        tf.keras.layers.Conv2D(32, 3, activation='relu', padding='same'),
        tf.keras.layers.MaxPooling2D(2),
        tf.keras.layers.Dropout(0.25),
        tf.keras.layers.Conv2D(64, 3, activation='relu', padding='same'),
        tf.keras.layers.MaxPooling2D(2),
        tf.keras.layers.Dropout(0.25),
        tf.keras.layers.UpSampling2D(),
        tf.keras.layers.Conv2D(64, 3, activation='relu', padding='same'),
        tf.keras.layers.UpSampling2D(),
        tf.keras.layers.Conv2D(32, 3, activation='relu', padding='same'),
        tf.keras.layers.ZeroPadding2D(padding=((1, 0), (1, 0))),  # To get 25x25
        tf.keras.layers.Conv2D(1, 1, activation='sigmoid', padding='same')
    ])
    return model

# %%
model_focal = create_model()

def focal_loss(gamma=2.0, alpha=0.25):
    def loss_fn(y_true, y_pred):
        y_pred = tf.clip_by_value(y_pred, 1e-7, 1 - 1e-7)
        p_t = y_true * y_pred + (1 - y_true) * (1 - y_pred)
        alpha_t = y_true * alpha + (1 - y_true) * (1 - alpha)
        focal_loss = -alpha_t * tf.pow(1.0 - p_t, gamma) * tf.math.log(p_t)
        return tf.reduce_mean(focal_loss)
    return loss_fn

model_focal.compile(
    optimizer='adam',
    loss=focal_loss(),
    metrics=['accuracy', tf.keras.metrics.Recall(), tf.keras.metrics.Precision()]
)

early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

history_focal = model_focal.fit(
    X_train_np, Y_train_np,
    epochs=50,
    batch_size=16,
    validation_split=0.1,
    callbacks=[early_stopping],
    verbose=1
)
# Out:
# Epoch 1/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8337 - loss: 0.0648 - precision_3: 0.0757 - recall_3: 0.1068 - val_accuracy: 0.9214 - val_loss: 0.0310 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 2/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9247 - loss: 0.0300 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_accuracy: 0.9214 - val_loss: 0.0302 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 3/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9245 - loss: 0.0269 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_accuracy: 0.9214 - val_loss: 0.0294 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 4/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9240 - loss: 0.0262 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_accuracy: 0.9214 - val_loss: 0.0295 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 5/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9249 - loss: 0.0257 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_accuracy: 0.9214 - val_loss: 0.0282 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 6/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9245 - loss: 0.0253 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_accuracy: 0.9214 - val_loss: 0.0306 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 7/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9237 - loss: 0.0252 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_accuracy: 0.9214 - val_loss: 0.0283 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 8/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9231 - loss: 0.0248 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_accuracy: 0.9214 - val_loss: 0.0270 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 9/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9256 - loss: 0.0242 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_accuracy: 0.9214 - val_loss: 0.0277 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 10/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9244 - loss: 0.0239 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_accuracy: 0.9214 - val_loss: 0.0278 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 11/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9235 - loss: 0.0237 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_accuracy: 0.9214 - val_loss: 0.0265 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 12/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9264 - loss: 0.0231 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_accuracy: 0.9214 - val_loss: 0.0269 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 13/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9241 - loss: 0.0230 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_accuracy: 0.9214 - val_loss: 0.0252 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 14/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9246 - loss: 0.0226 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_accuracy: 0.9214 - val_loss: 0.0251 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 15/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9239 - loss: 0.0224 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_accuracy: 0.9214 - val_loss: 0.0244 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 16/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9240 - loss: 0.0220 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_accuracy: 0.9214 - val_loss: 0.0235 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 17/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9241 - loss: 0.0218 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_accuracy: 0.9214 - val_loss: 0.0237 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 18/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9245 - loss: 0.0218 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_accuracy: 0.9214 - val_loss: 0.0233 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 19/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9271 - loss: 0.0208 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_accuracy: 0.9214 - val_loss: 0.0228 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 20/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9236 - loss: 0.0209 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_accuracy: 0.9214 - val_loss: 0.0214 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 21/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9236 - loss: 0.0206 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_accuracy: 0.9214 - val_loss: 0.0214 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 22/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9252 - loss: 0.0199 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_accuracy: 0.9214 - val_loss: 0.0214 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 23/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9254 - loss: 0.0197 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_accuracy: 0.9214 - val_loss: 0.0210 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 24/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9254 - loss: 0.0196 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_accuracy: 0.9214 - val_loss: 0.0202 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 25/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9239 - loss: 0.0196 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_accuracy: 0.9214 - val_loss: 0.0199 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 26/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9240 - loss: 0.0195 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_accuracy: 0.9214 - val_loss: 0.0194 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 27/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9258 - loss: 0.0189 - precision_3: 0.1053 - recall_3: 3.8479e-06 - val_accuracy: 0.9214 - val_loss: 0.0191 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 28/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9241 - loss: 0.0191 - precision_3: 0.8105 - recall_3: 0.0030 - val_accuracy: 0.9214 - val_loss: 0.0188 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 29/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9261 - loss: 0.0184 - precision_3: 0.7690 - recall_3: 0.0031 - val_accuracy: 0.9215 - val_loss: 0.0187 - val_precision_3: 1.0000 - val_recall_3: 0.0012
# Epoch 30/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9240 - loss: 0.0186 - precision_3: 0.8094 - recall_3: 0.0045 - val_accuracy: 0.9216 - val_loss: 0.0185 - val_precision_3: 1.0000 - val_recall_3: 0.0043
# Epoch 31/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9239 - loss: 0.0186 - precision_3: 0.8343 - recall_3: 0.0092 - val_accuracy: 0.9214 - val_loss: 0.0180 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 32/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9246 - loss: 0.0184 - precision_3: 0.8487 - recall_3: 0.0064 - val_accuracy: 0.9214 - val_loss: 0.0183 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 33/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9246 - loss: 0.0182 - precision_3: 0.8811 - recall_3: 0.0059 - val_accuracy: 0.9216 - val_loss: 0.0177 - val_precision_3: 1.0000 - val_recall_3: 0.0043
# Epoch 34/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9257 - loss: 0.0177 - precision_3: 0.8260 - recall_3: 0.0118 - val_accuracy: 0.9218 - val_loss: 0.0176 - val_precision_3: 1.0000 - val_recall_3: 0.0065
# Epoch 35/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9267 - loss: 0.0177 - precision_3: 0.8999 - recall_3: 0.0130 - val_accuracy: 0.9221 - val_loss: 0.0174 - val_precision_3: 1.0000 - val_recall_3: 0.0105
# Epoch 36/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9240 - loss: 0.0177 - precision_3: 0.8799 - recall_3: 0.0247 - val_accuracy: 0.9225 - val_loss: 0.0171 - val_precision_3: 1.0000 - val_recall_3: 0.0167
# Epoch 37/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9258 - loss: 0.0173 - precision_3: 0.9161 - recall_3: 0.0274 - val_accuracy: 0.9223 - val_loss: 0.0170 - val_precision_3: 0.9787 - val_recall_3: 0.0142
# Epoch 38/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9261 - loss: 0.0171 - precision_3: 0.8033 - recall_3: 0.0202 - val_accuracy: 0.9230 - val_loss: 0.0168 - val_precision_3: 0.9877 - val_recall_3: 0.0247
# Epoch 39/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9279 - loss: 0.0167 - precision_3: 0.9161 - recall_3: 0.0326 - val_accuracy: 0.9232 - val_loss: 0.0167 - val_precision_3: 0.9886 - val_recall_3: 0.0268
# Epoch 40/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9251 - loss: 0.0170 - precision_3: 0.8599 - recall_3: 0.0319 - val_accuracy: 0.9233 - val_loss: 0.0168 - val_precision_3: 1.0000 - val_recall_3: 0.0275
# Epoch 41/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9247 - loss: 0.0169 - precision_3: 0.8925 - recall_3: 0.0245 - val_accuracy: 0.9241 - val_loss: 0.0165 - val_precision_3: 0.9371 - val_recall_3: 0.0413
# Epoch 42/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9260 - loss: 0.0165 - precision_3: 0.9284 - recall_3: 0.0318 - val_accuracy: 0.9240 - val_loss: 0.0163 - val_precision_3: 0.8084 - val_recall_3: 0.0651
# Epoch 43/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9254 - loss: 0.0163 - precision_3: 0.8676 - recall_3: 0.0467 - val_accuracy: 0.9228 - val_loss: 0.0162 - val_precision_3: 1.0000 - val_recall_3: 0.0185
# Epoch 44/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9271 - loss: 0.0160 - precision_3: 0.9205 - recall_3: 0.0498 - val_accuracy: 0.9246 - val_loss: 0.0160 - val_precision_3: 0.9872 - val_recall_3: 0.0475
# Epoch 45/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9254 - loss: 0.0165 - precision_3: 0.8960 - recall_3: 0.0373 - val_accuracy: 0.9248 - val_loss: 0.0157 - val_precision_3: 0.9937 - val_recall_3: 0.0487
# Epoch 46/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9258 - loss: 0.0166 - precision_3: 0.9431 - recall_3: 0.0371 - val_accuracy: 0.9252 - val_loss: 0.0158 - val_precision_3: 0.9791 - val_recall_3: 0.0577
# Epoch 47/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9255 - loss: 0.0162 - precision_3: 0.9107 - recall_3: 0.0477 - val_accuracy: 0.9230 - val_loss: 0.0160 - val_precision_3: 1.0000 - val_recall_3: 0.0213
# Epoch 48/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9266 - loss: 0.0159 - precision_3: 0.9294 - recall_3: 0.0426 - val_accuracy: 0.9260 - val_loss: 0.0157 - val_precision_3: 0.9508 - val_recall_3: 0.0774
# Epoch 49/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9263 - loss: 0.0159 - precision_3: 0.9310 - recall_3: 0.0590 - val_accuracy: 0.9256 - val_loss: 0.0161 - val_precision_3: 0.9760 - val_recall_3: 0.0626
# Epoch 50/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9268 - loss: 0.0157 - precision_3: 0.9250 - recall_3: 0.0586 - val_accuracy: 0.9251 - val_loss: 0.0154 - val_precision_3: 0.8842 - val_recall_3: 0.0706

# %%
def plot_history(history, title="Model"):
    plt.figure(figsize=(12, 4))
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'], label='Train')
    plt.plot(history.history['val_accuracy'], label='Validation')
    plt.title(f'{title} - Accuracy')
    plt.xlabel('Epoch')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'], label='Train')
    plt.plot(history.history['val_loss'], label='Validation')
    plt.title(f'{title} - Loss')
    plt.xlabel('Epoch')
    plt.legend()
    plt.tight_layout()
    plt.show()

plot_history(history_focal, "Focal Loss CNN")

# %%
from sklearn.metrics import f1_score

def find_optimal_threshold(y_true, y_pred):
    # Ensure both are numpy arrays
    y_true = y_true.astype(np.uint8)         # force to binary (0/1)
    y_pred = y_pred.astype(np.float32)       # keep as float for thresholding

    thresholds = np.linspace(0.1, 0.9, 50)
    f1_scores = []

    for t in thresholds:
        y_pred_bin = (y_pred > t).astype(np.uint8)
        f1 = f1_score(y_true.reshape(-1), y_pred_bin.reshape(-1))
        f1_scores.append(f1)

    best_t = thresholds[np.argmax(f1_scores)]

    plt.plot(thresholds, f1_scores, label='F1 Score')
    plt.axvline(best_t, color='red', linestyle='--', label=f'Best: {best_t:.3f}')
    plt.xlabel('Threshold')
    plt.ylabel('F1 Score')
    plt.title('Optimal Threshold Search')
    plt.legend()
    plt.grid(True)
    plt.show()

    return best_t

best_threshold = find_optimal_threshold(Y_test_np, y_pred_proba)
print(f"Best Threshold: {best_threshold:.3f}")
# Out:
# Best Threshold: 0.296

# %%
import matplotlib.pyplot as plt

def visualize_predictions_range(model, X, Y_true, start=0, end=5, threshold=0.5):
    """
    Visualizes predictions for samples in a given index range [start, end).
    Each row: Input | Ground Truth | Predicted Mask
    """
    y_pred = model.predict(X[start:end])
    
    num_samples = end - start
    plt.figure(figsize=(15, 4 * num_samples))
    
    for i in range(num_samples):
        idx = start + i
        
        # Original image
        plt.subplot(num_samples, 3, i * 3 + 1)
        plt.imshow(X[idx].squeeze(), cmap='viridis')
        plt.title(f'Input {idx}')
        plt.axis('off')

        # Ground truth
        plt.subplot(num_samples, 3, i * 3 + 2)
        plt.imshow(Y_true[idx].squeeze(), cmap='gray')
        plt.title('Ground Truth')
        plt.axis('off')

        # Prediction
        plt.subplot(num_samples, 3, i * 3 + 3)
        pred_mask = (y_pred[i] > threshold).squeeze()
        plt.imshow(pred_mask, cmap='gray')
        plt.title(f'Predicted (> {threshold:.2f})')
        plt.axis('off')
    
    plt.tight_layout()
    plt.show()

visualize_predictions_range(model_focal, X_test_np, Y_test_np, start=1, end=25, threshold=best_threshold)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
